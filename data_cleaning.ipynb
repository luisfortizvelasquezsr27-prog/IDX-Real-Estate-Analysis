# %%
import pandas as pd
import glob

# Get files
listing_files = sorted(glob.glob("CRMLSListing*.csv"))
sold_files = sorted(glob.glob("CRMLSSold*.csv"))

# Read and concatenate
listings_df = pd.concat(
    [pd.read_csv(file) for file in listing_files],
    ignore_index=True
)

sold_df = pd.concat(
    [pd.read_csv(file) for file in sold_files],
    ignore_index=True)

# Count rows
print("Listings files:", listing_files)
print("Sold files:", sold_files)

print("Listings rows:", len(listings_df))
print("Sold rows:", len(sold_df))

# Optional: preview
display(listings_df.head())
display(sold_df.head())
# Out:
# C:\Users\luisf\AppData\Local\Temp\ipykernel_32904\1811657651.py:15: DtypeWarning: Columns (4,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   [pd.read_csv(file) for file in sold_files],
# Listings files: ['CRMLSListing202602.csv', 'CRMLSListing202603.csv', 'CRMLSListing202604.csv', 'CRMLSListing202605.csv']
# Sold files: ['CRMLSSold202602.csv', 'CRMLSSold202603.csv', 'CRMLSSold202604.csv', 'CRMLSSold202605.csv']
# Listings rows: 134690
# Sold rows: 81338
#    OriginalListPrice  ListingKey   CloseDate  ClosePrice ListAgentFirstName  \
# 0          4050000.0  1174730817  2026-05-20   4050000.0             Stacey
# 1             4250.0  1174724259         NaN         NaN              Kevin
# 2           485000.0  1174691880         NaN         NaN             Carlos
# 3           449900.0  1174669033         NaN         NaN            Beverly
# 4          1600000.0  1174664157         NaN         NaN               Todd
#
#   ListAgentLastName   Latitude   Longitude        UnparsedAddress  \
# 0             Moore  33.975263 -118.398691   7400 El Manor Avenue
# 1            Yamada  33.874663 -118.318509  17122 Spinning Avenue
# 2          Elizondo  32.630594 -117.095432  468 Colorado Avenue B
# 3               Fry  38.236410 -120.345630         1919 Airacobra
# 4             Combs  34.736299 -120.256787          0 Bell Street
#
#        PropertyType  ...  MainLevelBedrooms  NewConstructionYN  GarageSpaces  \
# 0       Residential  ...                NaN              False           NaN
# 1  ResidentialLease  ...                4.0              False           2.0
# 2       Residential  ...                2.0                NaN           0.0
# 3       Residential  ...                NaN              False           0.0
# 4              Land  ...                NaN              False           NaN
#
#   HighSchoolDistrict PostalCode               BuyerOfficeName.1  \
# 0                NaN      90045  Sotheby's International Realty
# 1   Torrance Unified      90504                             NaN
# 2              Other      91910                             NaN
# 3                NaN  95223-000                             NaN
# 4                NaN      93440                             NaN
#
#   AssociationFee LotSizeSquareFeet MiddleOrJuniorSchoolDistrict  \
# 0           28.0            6153.0                          NaN
# 1            0.0            5490.0                          NaN
# 2          450.0            7840.8                          NaN
# 3          110.0           44431.0                          NaN
# 4            0.0         1214017.2                          NaN
#
#        UnparsedAddress.1
# 0   7400 El Manor Avenue
# 1  17122 Spinning Avenue
# 2  468 Colorado Avenue B
# 3         1919 Airacobra
# 4          0 Bell Street
#
# [5 rows x 81 columns]
#   BuyerAgentAOR           ListAgentAOR          Flooring ViewYN WaterfrontYN  \
# 0   PacificWest            PacificWest               NaN  False          NaN
# 1      SouthBay  BeverlyHillsGreaterLa  Carpet,Tile,Wood   True          NaN
# 2   ContraCosta            ContraCosta   Carpet,Laminate    NaN          NaN
# 3   ContraCosta            ContraCosta       Carpet,Tile   True          NaN
# 4   ContraCosta            ContraCosta  Carpet,Tile,Wood    NaN          NaN
#
#   BasementYN PoolPrivateYN  OriginalListPrice  ListingKey   CloseDate  ...  \
# 0        NaN         False          1113000.0  1174932366  2026-03-09  ...
# 1        NaN         False           849000.0  1174381872  2026-03-13  ...
# 2        NaN         False           545000.0  1172651278  2026-03-04  ...
# 3        NaN         False          8600000.0  1172651277  2026-03-13  ...
# 4        NaN         False          4675000.0  1172651275  2026-03-30  ...
#
#    MainLevelBedrooms NewConstructionYN GarageSpaces  HighSchoolDistrict  \
# 0                3.0             False          0.0         ABC Unified
# 1                NaN             False          NaN                 NaN
# 2                NaN             False          1.0                 NaN
# 3                NaN             False          5.0                 NaN
# 4                NaN             False          3.0                 NaN
#
#    PostalCode AssociationFee LotSizeSquareFeet  MiddleOrJuniorSchoolDistrict  \
# 0       90018            0.0            7501.0                           NaN
# 1       93041          196.0            4356.0                           NaN
# 2       94563          936.0               0.0                           NaN
# 3       94507            NaN          121532.0                           NaN
# 4       94507            NaN           20040.0                           NaN
#
#    OriginatingSystemName  OriginatingSystemSubName
# 0                  CRMLS                 CRMLS_CRM
# 1                  CRMLS                  CRMLS_CL
# 2                  CRMLS                CRMLS_CCBE
# 3                  CRMLS                CRMLS_CCBE
# 4                  CRMLS                CRMLS_CCBE
#
# [5 rows x 79 columns]

# %% [markdown]
# # Weeks 2–3 – Dataset Structuring, Validation & Mortgage Rate Enrichment

# %% [markdown]
# ## Dataset Understanding

# %%
# --- Dataset shape and dtypes ---
print("=== LISTINGS DATASET ===")
print(f"Shape: {listings_df.shape[0]:,} rows x {listings_df.shape[1]} columns")
print("\nColumn dtypes:")
print(listings_df.dtypes.to_string())

print("\n=== SOLD DATASET ===")
print(f"Shape: {sold_df.shape[0]:,} rows x {sold_df.shape[1]} columns")
print("\nColumn dtypes:")
print(sold_df.dtypes.to_string())

# %%
# --- Unique PropertyType values in both datasets ---
print("Listings PropertyType values:")
print(listings_df['PropertyType'].value_counts(dropna=False))

print("\nSold PropertyType values:")
print(sold_df['PropertyType'].value_counts(dropna=False))

# %% [markdown]
# ## Filter to Residential Only

# %%
# --- Filter both datasets to Residential only ---
listings_rows_before = len(listings_df)
sold_rows_before = len(sold_df)

listings_res = listings_df[listings_df['PropertyType'] == 'Residential'].copy()
sold_res = sold_df[sold_df['PropertyType'] == 'Residential'].copy()

print("LISTINGS:")
print(f"  Before filter: {listings_rows_before:,} rows")
print(f"  After  filter: {len(listings_res):,} rows")
print(f"  Dropped:       {listings_rows_before - len(listings_res):,} rows")

print("\nSOLD:")
print(f"  Before filter: {sold_rows_before:,} rows")
print(f"  After  filter: {len(sold_res):,} rows")
print(f"  Dropped:       {sold_rows_before - len(sold_res):,} rows")

# %% [markdown]
# ## Missing Value Analysis

# %%
def missing_report(df, name):
    total = len(df)
    missing = df.isnull().sum()
    pct = (missing / total * 100).round(2)
    report = pd.DataFrame({'missing_count': missing, 'missing_pct': pct})
    report = report[report['missing_count'] > 0].sort_values('missing_pct', ascending=False)
    print(f"\n=== {name} – Missing Value Report ({total:,} rows) ===")
    print(report.to_string())
    high_missing = report[report['missing_pct'] > 90]
    print(f"\nColumns with >90% missing ({len(high_missing)}):")
    print(high_missing.to_string() if len(high_missing) else "  None")
    return report

listings_missing = missing_report(listings_res, "LISTINGS (Residential)")
sold_missing     = missing_report(sold_res,     "SOLD (Residential)")

# %% [markdown]
# ## Numeric Distribution Review

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import numpy as np

# Fields to review (using sold_res as the primary analytics dataset)
numeric_fields = [
    'ClosePrice', 'ListPrice', 'OriginalListPrice',
    'LivingArea', 'LotSizeAcres', 'BedroomsTotal',
    'BathroomsTotalInteger', 'DaysOnMarket', 'YearBuilt'
]

# Keep only fields that actually exist in sold_res
numeric_fields = [f for f in numeric_fields if f in sold_res.columns]

# --- Percentile summary table ---
percentiles = [0.01, 0.05, 0.10, 0.25, 0.50, 0.75, 0.90, 0.95, 0.99]
summary = sold_res[numeric_fields].describe(percentiles=percentiles)
print("=== SOLD (Residential) – Numeric Distribution Summary ===")
print(summary.to_string())

# Highlighted fields required by deliverable
for col in ['ClosePrice', 'LivingArea', 'DaysOnMarket']:
    if col in sold_res.columns:
        s = sold_res[col].dropna()
        print(f"\n--- {col} ---")
        print(f"  count:  {s.count():,}")
        print(f"  mean:   {s.mean():,.2f}")
        print(f"  median: {s.median():,.2f}")
        print(f"  min:    {s.min():,.2f}")
        print(f"  max:    {s.max():,.2f}")
        print(f"  p25:    {s.quantile(0.25):,.2f}")
        print(f"  p75:    {s.quantile(0.75):,.2f}")

# %%
# --- Histograms for all numeric fields ---
n_cols = 3
n_rows = int(np.ceil(len(numeric_fields) / n_cols))
fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, n_rows * 4))
axes = axes.flatten()

for i, col in enumerate(numeric_fields):
    data = sold_res[col].dropna()
    # Cap at 99th percentile for readability
    cap = data.quantile(0.99)
    data_capped = data[data <= cap]
    axes[i].hist(data_capped, bins=50, color='steelblue', edgecolor='white', linewidth=0.3)
    axes[i].set_title(col, fontsize=12, fontweight='bold')
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Count')
    axes[i].xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))
    axes[i].tick_params(axis='x', rotation=30)

# Hide any unused subplots
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.suptitle('Sold (Residential) – Numeric Field Distributions (capped at 99th pct)', fontsize=14, y=1.01)
plt.tight_layout()
plt.show()

# %%
# --- Boxplots for all numeric fields ---
fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, n_rows * 4))
axes = axes.flatten()

for i, col in enumerate(numeric_fields):
    data = sold_res[col].dropna()
    cap = data.quantile(0.99)
    data_capped = data[data <= cap]
    axes[i].boxplot(data_capped, vert=True, patch_artist=True,
                    boxprops=dict(facecolor='steelblue', alpha=0.6))
    axes[i].set_title(col, fontsize=12, fontweight='bold')
    axes[i].set_ylabel('Value')
    axes[i].yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'{x:,.0f}'))

for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.suptitle('Sold (Residential) – Boxplots (capped at 99th pct)', fontsize=14, y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Suggested Intern Questions (EDA Answers)

# %%
# Q1 – Residential vs. other property type share
print("=== Q1: PropertyType share (SOLD) ===")
pt_share = sold_df['PropertyType'].value_counts(dropna=False)
pt_pct   = (pt_share / len(sold_df) * 100).round(2)
print(pd.DataFrame({'count': pt_share, 'pct': pt_pct}).to_string())

# Q2 – Median and average close prices
print(f"\n=== Q2: ClosePrice stats (Residential Sold) ===")
print(f"  Median:  ${sold_res['ClosePrice'].median():,.0f}")
print(f"  Average: ${sold_res['ClosePrice'].mean():,.0f}")

# Q3 – Days on Market distribution
print(f"\n=== Q3: DaysOnMarket distribution ===")
dom = sold_res['DaysOnMarket'].dropna()
print(f"  Median:  {dom.median():.0f} days")
print(f"  Mean:    {dom.mean():.1f} days")
print(f"  p25:     {dom.quantile(0.25):.0f} days")
print(f"  p75:     {dom.quantile(0.75):.0f} days")
print(f"  p90:     {dom.quantile(0.90):.0f} days")

# Q4 – % sold above vs. below list price
print(f"\n=== Q4: Sold above vs. below OriginalListPrice ===")
valid = sold_res[['ClosePrice', 'OriginalListPrice']].dropna()
above = (valid['ClosePrice'] >= valid['OriginalListPrice']).sum()
below = (valid['ClosePrice'] <  valid['OriginalListPrice']).sum()
print(f"  At or above list: {above:,}  ({above/len(valid)*100:.1f}%)")
print(f"  Below list:       {below:,}  ({below/len(valid)*100:.1f}%)")

# Q5 – Date consistency issues (close before listing)
sold_res['CloseDate_dt']          = pd.to_datetime(sold_res['CloseDate'], errors='coerce')
sold_res['ListingContractDate_dt'] = pd.to_datetime(sold_res['ListingContractDate'], errors='coerce')
bad_dates = (sold_res['CloseDate_dt'] < sold_res['ListingContractDate_dt']).sum()
print(f"\n=== Q5: CloseDate before ListingContractDate ===")
print(f"  Flagged records: {bad_dates:,}")

# Q6 – Counties with highest median close price
print(f"\n=== Q6: Top 10 counties by median ClosePrice ===")
county_col = 'CountyOrParish' if 'CountyOrParish' in sold_res.columns else None
if county_col:
    county_median = (
        sold_res.groupby(county_col)['ClosePrice']
        .median()
        .sort_values(ascending=False)
        .head(10)
    )
    print(county_median.apply(lambda x: f"${x:,.0f}").to_string())
else:
    print("  CountyOrParish column not found")

# %% [markdown]
# ## Mortgage Rate Enrichment (FRED MORTGAGE30US)

# %%
# Step 1 – Fetch the 30-year fixed mortgage rate series from FRED
url = "https://fred.stlouisfed.org/graph/fredgraph.csv?id=MORTGAGE30US"
mortgage = pd.read_csv(url, parse_dates=['observation_date'])
mortgage.columns = ['date', 'rate_30yr_fixed']

# Drop any rows where the rate is missing (FRED uses '.' as placeholder for future dates)
mortgage = mortgage[pd.to_numeric(mortgage['rate_30yr_fixed'], errors='coerce').notna()].copy()
mortgage['rate_30yr_fixed'] = mortgage['rate_30yr_fixed'].astype(float)

print(f"FRED data fetched: {len(mortgage):,} weekly observations")
print(f"Date range: {mortgage['date'].min().date()} → {mortgage['date'].max().date()}")
print(mortgage.tail())

# Step 2 – Resample weekly → monthly average
mortgage['year_month'] = mortgage['date'].dt.to_period('M')
mortgage_monthly = (
    mortgage.groupby('year_month')['rate_30yr_fixed']
    .mean()
    .reset_index()
)
print(f"\nMonthly averages: {len(mortgage_monthly)} months")
print(mortgage_monthly.tail())

# %%
# Step 3 – Create year_month keys on the MLS datasets
# Sold: key off CloseDate
sold_res['year_month'] = pd.to_datetime(sold_res['CloseDate'], errors='coerce').dt.to_period('M')

# Listings: key off ListingContractDate
listings_res['year_month'] = pd.to_datetime(
    listings_res['ListingContractDate'], errors='coerce'
).dt.to_period('M')

# Step 4 – Left-merge mortgage rates onto both datasets
sold_with_rates     = sold_res.merge(mortgage_monthly, on='year_month', how='left')
listings_with_rates = listings_res.merge(mortgage_monthly, on='year_month', how='left')

# Step 5 – Validate: no nulls expected for months covered by the FRED series
sold_null_rates     = sold_with_rates['rate_30yr_fixed'].isnull().sum()
listings_null_rates = listings_with_rates['rate_30yr_fixed'].isnull().sum()

print("=== Merge Validation ===")
print(f"Sold     – null rate_30yr_fixed: {sold_null_rates}")
print(f"Listings – null rate_30yr_fixed: {listings_null_rates}")

# Preview
print("\nSold sample (CloseDate / year_month / ClosePrice / rate):")
print(
    sold_with_rates[['CloseDate', 'year_month', 'ClosePrice', 'rate_30yr_fixed']]
    .dropna(subset=['rate_30yr_fixed'])
    .head()
    .to_string()
)

# %% [markdown]
# ## Save Output CSVs

# %%
# Filtered (Residential-only) datasets
listings_res.drop(columns=['year_month'], errors='ignore').to_csv('listings_residential.csv', index=False)
sold_res.drop(columns=['year_month', 'CloseDate_dt', 'ListingContractDate_dt'], errors='ignore').to_csv('sold_residential.csv', index=False)

# Enriched datasets with mortgage rates
# Convert Period column to string so CSV writes cleanly
sold_with_rates['year_month']     = sold_with_rates['year_month'].astype(str)
listings_with_rates['year_month'] = listings_with_rates['year_month'].astype(str)

sold_with_rates.drop(columns=['CloseDate_dt', 'ListingContractDate_dt'], errors='ignore').to_csv('sold_residential_with_rates.csv', index=False)
listings_with_rates.to_csv('listings_residential_with_rates.csv', index=False)

print("Saved:")
print(f"  listings_residential.csv              – {len(listings_res):,} rows")
print(f"  sold_residential.csv                  – {len(sold_res):,} rows")
print(f"  sold_residential_with_rates.csv       – {len(sold_with_rates):,} rows")
print(f"  listings_residential_with_rates.csv   – {len(listings_with_rates):,} rows")
